# %%
import pandas as pd
df = pd.read_csv('assets/vgsales.csv')
import numpy as np

# %%
df.head(1)
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
publisher = df['Publisher']
top_publisher = publisher.value_counts()
top_publisher.head(1)
# Out:
# Electronic Arts    1351
# Name: Publisher, dtype: int64

# %%
platform = df['Platform']
top_platform = platform.value_counts()
top_platform.head(1)
# Out:
# DS    2163
# Name: Platform, dtype: int64

# %%
genre = df['Genre']
top_genre = genre.value_counts()
top_genre.head(1)
# Out:
# Action    3316
# Name: Genre, dtype: int64

# %%
name_gross = df[['Name', 'Global_Sales']]
top_20_games = name_gross.sort_values('Global_Sales', ascending=False)
top_20_games.head(20)
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %%
na_sales = df['NA_Sales']
median_sales = na_sales.median()
median_sales
# Out:
# 0.08

# %%
df.loc[na_sales== .08]
# Out:
#         Rank                                               Name Platform  \
# 446      447                                  Dragon Warrior IV      NES
# 497      498        World Soccer Winning Eleven 7 International      PS2
# 1617    1619                             Farming Simulator 2015       PC
# 1926    1928                          Pro Evolution Soccer 2008     X360
# 2067    2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# ...      ...                                                ...      ...
# 11403  11405            My English Coach: Para Hispanoparlantes       DS
# 11431  11433   Little League World Series Baseball: Double Play       DS
# 11432  11434                               DanceDanceRevolution     X360
# 11455  11457                                         The Hidden      3DS
# 11492  11494                       Ultimate Shooting Collection      Wii
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
na_sales.head(1)
# Out:
# 0    41.49
# Name: NA_Sales, dtype: float64

# %%
na_sales.mean()
# Out:
# 0.26466742981082064

# %%
df.loc[na_sales== 0.26].head(1)
# Out:
#      Rank                Name Platform    Year Genre  \
# 900   902  PaRappa The Rapper       PS  1996.0  Misc
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 900  Sony Computer Entertainment      0.26      0.16      1.46         0.03
#
#      Global_Sales
# 900          1.92

# %%
platform_global = df[['Platform', 'Global_Sales']]
platform_global.head(1)
# Out:
#   Platform  Global_Sales
# 0      Wii         82.74
